# %%
#import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('LifeExpectancy.csv')

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0    6.0               8.16        65.0       0.1  584.259210  33736494.0
# 1   58.0               8.18        62.0       0.1  612.696514    327582.0
# 2   62.0               8.13        64.0       0.1  631.744976  31731688.0
# 3   67.0               8.52        67.0       0.1  669.959000   3696958.0
# 4   68.0               7.87        68.0       0.1   63.537231   2978599.0
#
#    thinness  1-19 years  thinness 5-9 years  Income composition of resources  \
# 0                  17.2                17.3                            0.479
# 1                  17.5                17.5                            0.476
# 2                  17.7                17.7                            0.470
# 3                  17.9                18.0                            0.463
# 4                  18.2                18.2                            0.454
#
#    Schooling
# 0       10.1
# 1       10.0
# 2        9.9
# 3        9.8
# 4        9.5
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (2938, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10  BMI                              2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
#  12  Polio                            2919 non-null   float64
#  13  Total expenditure                2712 non-null   float64
#  14  Diphtheria                       2919 non-null   float64
#  15  HIV/AIDS                         2938 non-null   float64
#  16  GDP                              2490 non-null   float64
#  17  Population                       2286 non-null   float64
#  18  thinness  1-19 years             2904 non-null   float64
#  19  thinness 5-9 years               2904 non-null   float64
#  20  Income composition of resources  2771 non-null   float64
#  21  Schooling                        2775 non-null   float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 505.1+ KB

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
# BMI                                 34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         652
# thinness  1-19 years                34
# thinness 5-9 years                  34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %% [markdown]
# # EDA (Data Cleaning & Filtering Outliers)

# %%
#use linear interpolate to fill in missing data

for col in df.columns:
 df[col] = df[col].interpolate(method='linear',limit_direction='both')

# %%
df.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
# BMI                                0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
# HIV/AIDS                           0
# GDP                                0
# Population                         0
# thinness  1-19 years               0
# thinness 5-9 years                 0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
# Detecting & Filtering Outliers using s with the IQR score
fig, axes = plt.subplots(7,2,figsize=(10,25))
df.boxplot(column='Population', ax=axes[0,0])

df.boxplot(column='Schooling',ax=axes[0,1])

df.boxplot(column='Income composition of resources',ax=axes[1,0])
df.boxplot(column='GDP',ax=axes[1,1])

df.boxplot(column='Total expenditure',ax=axes[2,0])
df.boxplot(column='Polio',ax=axes[2,1])

df.boxplot(column='Adult Mortality',ax=axes[3,0])
df.boxplot(column='Alcohol',ax=axes[3,1])

df.boxplot(column='Hepatitis B',ax=axes[4,0])
df.boxplot(column='thinness 5-9 years',ax=axes[4,1])

df.boxplot(column='BMI',ax=axes[5,0])
df.boxplot(column='under-five deaths',ax=axes[5,1])

df.boxplot(column='HIV/AIDS',ax=axes[6,0])
df.boxplot(column='Diphtheria',ax=axes[6,1])

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Year                               8.000000e+00
# Life expectancy                    1.250000e+01
# Adult Mortality                    1.540000e+02
# infant deaths                      2.200000e+01
# Alcohol                            6.647500e+00
# percentage expenditure             4.368488e+02
# Hepatitis B                        2.500000e+01
# Measles                            3.602500e+02
# BMI                                3.677500e+01
# under-five deaths                  2.800000e+01
# Polio                              1.900000e+01
# Total expenditure                  3.127500e+00
# Diphtheria                         1.900000e+01
# HIV/AIDS                           7.000000e-01
# GDP                                6.635257e+03
# Population                         7.954483e+06
# thinness  1-19 years               5.600000e+00
# thinness 5-9 years                 5.700000e+00
# Income composition of resources    2.911071e-01
# Schooling                          4.100000e+00
# dtype: float64

# %%
#using the IQR formular to clean the data
df_clean = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
df_clean.shape
# Out:
# (1117, 22)

# %%
df_clean.corr()
# Out:
#                                      Year  Life expectancy  Adult Mortality  \
# Year                             1.000000         0.046186        -0.026471
# Life expectancy                  0.046186         1.000000        -0.564329
# Adult Mortality                 -0.026471        -0.564329         1.000000
# infant deaths                    0.062363        -0.333388         0.230186
# Alcohol                         -0.136004         0.406726        -0.105939
# percentage expenditure          -0.041569         0.324035        -0.197141
# Hepatitis B                      0.153244         0.154186        -0.144125
# Measles                          0.032863        -0.113293         0.081875
# BMI                             -0.015976         0.386781        -0.255414
# under-five deaths                0.071424        -0.376161         0.246407
# Polio                           -0.030733         0.346108        -0.190374
# Total expenditure                0.036035         0.274791        -0.145796
# Diphtheria                       0.022674         0.357826        -0.192808
# HIV/AIDS                         0.003294        -0.484477         0.331473
# GDP                              0.058686         0.151110        -0.043454
# Population                       0.001704         0.016706         0.002054
# thinness  1-19 years             0.025769        -0.390887         0.166043
# thinness 5-9 years               0.035145        -0.389912         0.169304
# Income composition of resources  0.012818         0.805275        -0.438029
# Schooling                        0.068773         0.681330        -0.355802
#
#                                  infant deaths   Alcohol  \
# Year                                  0.062363 -0.136004
# Life expectancy                      -0.333388  0.406726
# Adult Mortality                       0.230186 -0.105939
# infant deaths                         1.000000 -0.273842
# Alcohol                              -0.273842  1.000000
# percentage expenditure               -0.135409  0.158691
# Hepatitis B                          -0.122990  0.117749
# Measles                               0.304604 -0.111140
# BMI                                  -0.165646  0.245870
# under-five deaths                     0.990827 -0.280712
# Polio                                -0.194155  0.262291
# Total expenditure                    -0.078475  0.300141
# Diphtheria                           -0.197169  0.270393
# HIV/AIDS                              0.160815 -0.190044
# GDP                                  -0.100949  0.269904
# Population                            0.196528  0.008718
# thinness  1-19 years                  0.230328 -0.392228
# thinness 5-9 years                    0.224847 -0.385471
# Income composition of resources      -0.370746  0.546137
# Schooling                            -0.342771  0.488217
#
#                                  percentage expenditure  Hepatitis B  \
# Year                                          -0.041569     0.153244
# Life expectancy                                0.324035     0.154186
# Adult Mortality                               -0.197141    -0.144125
# infant deaths                                 -0.135409    -0.122990
# Alcohol                                        0.158691     0.117749
# percentage expenditure                         1.000000     0.063083
# Hepatitis B                                    0.063083     1.000000
# Measles                                       -0.046848    -0.086199
# BMI                                            0.176364     0.093393
# under-five deaths                             -0.149709    -0.138650
# Polio                                          0.099510     0.579782
# Total expenditure                              0.120599     0.087311
# Diphtheria                                     0.122829     0.618393
# HIV/AIDS                                      -0.153798    -0.185202
# GDP                                            0.276896     0.099585
# Population                                     0.047876     0.046312
# thinness  1-19 years                          -0.154892    -0.022081
# thinness 5-9 years                            -0.160608    -0.026047
# Income composition of resources                0.294088     0.205560
# Schooling                                      0.294369     0.189146
#
#                                   Measles       BMI  under-five deaths  \
# Year                             0.032863 -0.015976           0.071424
# Life expectancy                 -0.113293  0.386781          -0.376161
# Adult Mortality                  0.081875 -0.255414           0.246407
# infant deaths                    0.304604 -0.165646           0.990827
# Alcohol                         -0.111140  0.245870          -0.280712
# percentage expenditure          -0.046848  0.176364          -0.149709
# Hepatitis B                     -0.086199  0.093393          -0.138650
# Measles                          1.000000 -0.085606           0.309308
# BMI                             -0.085606  1.000000          -0.197933
# under-five deaths                0.309308 -0.197933           1.000000
# Polio                           -0.076544  0.122247          -0.217930
# Total expenditure               -0.103122  0.177492          -0.084952
# Diphtheria                      -0.064787  0.131703          -0.219652
# HIV/AIDS                         0.057060 -0.288259           0.206854
# GDP                             -0.030443  0.133144          -0.114807
# Population                       0.082037  0.074976           0.192571
# thinness  1-19 years             0.196054 -0.511788           0.258271
# thinness 5-9 years               0.192717 -0.517439           0.249987
# Income composition of resources -0.085280  0.433088          -0.412359
# Schooling                       -0.086419  0.389796          -0.375279
#
#                                     Polio  Total expenditure  Diphtheria  \
# Year                            -0.030733           0.036035    0.022674
# Life expectancy                  0.346108           0.274791    0.357826
# Adult Mortality                 -0.190374          -0.145796   -0.192808
# infant deaths                   -0.194155          -0.078475   -0.197169
# Alcohol                          0.262291           0.300141    0.270393
# percentage expenditure           0.099510           0.120599    0.122829
# Hepatitis B                      0.579782           0.087311    0.618393
# Measles                         -0.076544          -0.103122   -0.064787
# BMI                              0.122247           0.177492    0.131703
# under-five deaths               -0.217930          -0.084952   -0.219652
# Polio                            1.000000           0.129426    0.926978
# Total expenditure                0.129426           1.000000    0.142709
# Diphtheria                       0.926978           0.142709    1.000000
# HIV/AIDS                        -0.212202          -0.051191   -0.196335
# GDP                              0.148568           0.000783    0.124325
# Population                       0.019577           0.005538    0.034146
# thinness  1-19 years            -0.092547          -0.304384   -0.087215
# thinness 5-9 years              -0.101679          -0.308992   -0.092947
# Income composition of resources  0.424792           0.198113    0.391832
# Schooling                        0.362249           0.239023    0.331634
#
#                                  HIV/AIDS       GDP  Population  \
# Year                             0.003294  0.058686    0.001704
# Life expectancy                 -0.484477  0.151110    0.016706
# Adult Mortality                  0.331473 -0.043454    0.002054
# infant deaths                    0.160815 -0.100949    0.196528
# Alcohol                         -0.190044  0.269904    0.008718
# percentage expenditure          -0.153798  0.276896    0.047876
# Hepatitis B                     -0.185202  0.099585    0.046312
# Measles                          0.057060 -0.030443    0.082037
# BMI                             -0.288259  0.133144    0.074976
# under-five deaths                0.206854 -0.114807    0.192571
# Polio                           -0.212202  0.148568    0.019577
# Total expenditure               -0.051191  0.000783    0.005538
# Diphtheria                      -0.196335  0.124325    0.034146
# HIV/AIDS                         1.000000 -0.209003   -0.045039
# GDP                             -0.209003  1.000000    0.074426
# Population                      -0.045039  0.074426    1.000000
# thinness  1-19 years             0.224984 -0.091906   -0.088060
# thinness 5-9 years               0.211179 -0.090763   -0.098461
# Income composition of resources -0.554309  0.339521    0.073797
# Schooling                       -0.483849  0.273128    0.039057
#
#                                  thinness  1-19 years  thinness 5-9 years  \
# Year                                         0.025769            0.035145
# Life expectancy                             -0.390887           -0.389912
# Adult Mortality                              0.166043            0.169304
# infant deaths                                0.230328            0.224847
# Alcohol                                     -0.392228           -0.385471
# percentage expenditure                      -0.154892           -0.160608
# Hepatitis B                                 -0.022081           -0.026047
# Measles                                      0.196054            0.192717
# BMI                                         -0.511788           -0.517439
# under-five deaths                            0.258271            0.249987
# Polio                                       -0.092547           -0.101679
# Total expenditure                           -0.304384           -0.308992
# Diphtheria                                  -0.087215           -0.092947
# HIV/AIDS                                     0.224984            0.211179
# GDP                                         -0.091906           -0.090763
# Population                                  -0.088060           -0.098461
# thinness  1-19 years                         1.000000            0.980468
# thinness 5-9 years                           0.980468            1.000000
# Income composition of resources             -0.418260           -0.415527
# Schooling                                   -0.395640           -0.390543
#
#                                  Income composition of resources  Schooling
# Year                                                    0.012818   0.068773
# Life expectancy                                         0.805275   0.681330
# Adult Mortality                                        -0.438029  -0.355802
# infant deaths                                          -0.370746  -0.342771
# Alcohol                                                 0.546137   0.488217
# percentage expenditure                                  0.294088   0.294369
# Hepatitis B                                             0.205560   0.189146
# Measles                                                -0.085280  -0.086419
# BMI                                                     0.433088   0.389796
# under-five deaths                                      -0.412359  -0.375279
# Polio                                                   0.424792   0.362249
# Total expenditure                                       0.198113   0.239023
# Diphtheria                                              0.391832   0.331634
# HIV/AIDS                                               -0.554309  -0.483849
# GDP                                                     0.339521   0.273128
# Population                                              0.073797   0.039057
# thinness  1-19 years                                   -0.418260  -0.395640
# thinness 5-9 years                                     -0.415527  -0.390543
# Income composition of resources                         1.000000   0.884262
# Schooling                                               0.884262   1.000000

# %%
df_clean.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
# BMI                                0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
# HIV/AIDS                           0
# GDP                                0
# Population                         0
# thinness  1-19 years               0
# thinness 5-9 years                 0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df_clean.corr(),cmap='viridis',annot=True)

# %% [markdown]
# # **Linear Regression Univariate**

# %%
#choosing our variables
X = df_clean[['Schooling']]
y = df_clean['Life expectancy']

# %%
#splitting the data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
#Training the Model
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Model Evaluation

# %%
print('Coefficients:\n',lm.coef_)
print('\n')
print('Intercept:\n',lm.intercept_)
# Out:
# Coefficients:
#  [1.60319494]
#
#
# Intercept:
#  51.67966448295152

# %%
#get the coefficient
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#            Coefficient
# Schooling     1.603195

# %% [markdown]
# ## Predictions

# %%
predictions = lm.predict(X_test)

# %%
plt.figure(figsize=(12,8))
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %% [markdown]
# ## Regression Evaluation Metrics

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 3.214284706065737
# MSE: 17.196979047534075
# RMSE: 4.146924046511351

# %%
# print the intercept
print(lm.intercept_)
# Out:
# 51.67966448295152

# %%
#the residuals
sns.distplot((y_test-predictions),bins=50);

# %%
predictions
# Out:
# array([74.44503268, 74.12439369, 73.6434352 , 71.39896228, 69.95608683,
#        71.71960127, 72.68151824, 76.5291861 , 72.68151824, 77.17046408,
#        74.44503268, 76.36886661, 73.8037547 , 75.22699919, 70.27672582,
#        72.36087925, 71.87992077, 71.07832329, 75.72758863, 73.00215723,
#        75.08631065, 68.35289189, 72.36087925, 74.60535217, 67.87193341,
#        75.56726914, 75.56726914, 65.62746049, 73.00215723, 74.78857445,
#        74.44503268, 71.23864279, 76.20854711, 73.96407419, 70.27672582,
#        62.26075111, 69.95608683, 72.20055975, 68.0322529 , 66.26873847,
#        76.84982509, 69.15448936, 77.65142256, 73.48311571, 71.87992077,
#        73.16247672, 69.15448936, 72.84183773, 76.04822762, 70.9180038 ,
#        71.39896228, 72.20055975, 72.36087925, 72.36087925, 73.16247672,
#        72.68151824, 68.99416987, 68.51321139, 74.60535217, 74.76567166,
#        75.72758863, 73.8037547 , 76.36886661, 79.73557599, 72.20055975,
#        64.50522403, 72.04024026, 59.6956392 , 67.07033594, 77.85754763,
#        76.36886661, 65.62746049, 72.84183773, 73.6925126 , 68.83385037,
#        69.31480886, 75.56726914, 72.84183773, 68.1925724 , 68.83385037,
#        71.87992077, 73.96407419, 73.00215723, 71.87992077, 73.00215723,
#        75.72758863, 67.55129442, 72.20055975, 68.99416987, 73.00215723,
#        74.44503268, 66.10841897, 71.71960127, 77.01014458, 69.47512835,
#        72.20055975, 74.60535217, 77.49110307, 72.36087925, 76.04822762,
#        71.71960127, 71.23864279, 74.60535217, 66.58937745, 73.16247672,
#        72.52119874, 74.76567166, 71.23864279, 68.83385037, 69.31480886,
#        76.20854711, 77.01014458, 69.79576734, 73.00215723, 75.08631065,
#        71.87992077, 75.72758863, 69.47512835, 70.9180038 , 72.36087925,
#        72.04024026, 71.23864279, 69.63544785, 77.33078357, 74.44503268,
#        71.71960127, 77.49110307, 75.24663015, 68.67353088, 72.20055975,
#        74.83368599, 75.08631065, 76.20854711, 75.40694964, 59.6956392 ,
#        71.87992077, 72.52119874, 68.0322529 , 72.84183773, 69.63544785,
#        73.32279622, 68.99416987, 74.60535217, 71.07832329, 68.1925724 ,
#        72.84183773, 71.39896228, 70.9180038 , 73.96407419, 73.48311571,
#        68.67353088, 74.44503268, 74.44503268, 76.6895056 , 70.75768431,
#        72.68151824, 69.15448936, 72.68151824, 71.87992077, 72.20055975,
#        73.32279622, 74.60535217, 71.55928178, 66.10841897, 75.88790812,
#        75.08145249, 69.47512835, 74.76567166, 71.71960127, 72.36087925,
#        71.39896228, 72.20055975, 73.48311571, 76.36886661, 73.16247672,
#        68.35289189, 61.94011212, 76.20854711, 70.27672582, 72.04024026,
#        68.83385037, 75.88790812, 70.11640633, 73.32279622, 75.56726914,
#        70.59736481, 77.65142256, 68.99416987, 70.27672582, 77.33078357,
#        75.24663015, 73.00215723, 68.83385037, 71.39896228, 76.20854711,
#        68.67353088, 73.32279622, 74.92599116, 74.76567166, 72.52119874,
#        73.96407419, 73.25408786, 77.01014458, 73.8037547 , 67.39097493,
#        70.11640633, 67.55129442, 78.51518473, 77.49110307, 69.47512835,
#        73.03487549, 68.67353088, 75.24663015, 71.55928178, 74.60535217,
#        73.32279622, 71.07832329, 72.04024026, 71.87992077, 74.28471318,
#        74.28471318, 75.72758863, 72.84183773, 70.59736481])

# %% [markdown]
# ## Optimization using Gradient Descent

# %%
# plotting the Test set
plt.figure(figsize=(12,8))
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train, lm.predict(X_train), color = 'blue')
plt.title('Life Expectancy vs Schooling (Test set)')
plt.xlabel('Schooling')
plt.ylabel('Life expectancy')
plt.show()

# %%
#the gradient descent function

#choosing our variables
X = X_train['Schooling']
Y = y_train

# %%
# Building the model
m = 0
c = 0

L = 0.0001  # The learning Rate
epochs = 1000  # The number of iterations to perform gradient descent

n = float(len(X)) # Number of elements in X

# Performing Gradient Descent 
for i in range(epochs): 
    Y_pred = m*X + c  # The current predicted value of Y
    D_m = (-2/n) * sum(X * (Y - Y_pred))  # Derivative wrt m
    D_c = (-2/n) * sum(Y - Y_pred)  # Derivative wrt c
    m = m - L * D_m  # Update m
    c = c - L * D_c  # Update c
    
print (m, c)
# Out:
# 5.4080380625727305 0.7556514022519032

# %%
# Making predictions
Y_pred = m*X + c
plt.figure(figsize=(12,8))
plt.scatter(X, Y)
plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red') # predicted
plt.title('Life Expectancy vs Schooling (Test set)')
plt.xlabel('Schooling')
plt.ylabel('Life expectancy')
plt.show()

# %%
Y_pred
# Out:
# 659     80.253811
# 1922    93.233102
# 1150    56.458443
# 38      71.600950
# 1305    68.896931
#           ...
# 1554    56.458443
# 2554    61.866482
# 228     84.580241
# 1639    79.713007
# 2249    52.132013
# Name: Schooling, Length: 893, dtype: float64

# %% [markdown]
# old equation
#
# y=1.60319494x+51.67966448295152
#
# new equation
#
# y=5.417787503836531x+0.7367669213503176

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_train, Y_pred))
print('MSE:', metrics.mean_squared_error(y_train, Y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_train, Y_pred)))
# Out:
# MAE: 8.084690713493016
# MSE: 105.58932788851375
# RMSE: 10.275666785591763

# %% [markdown]
# ## from the last figure, we can see that our points are nearer to line as compared to the previous
